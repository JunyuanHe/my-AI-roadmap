# %% [markdown]
# ## Music generation with LSTMs

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install comet_ml
# Out:
# Requirement already satisfied: comet_ml in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (3.58.0)
# Requirement already satisfied: dulwich!=0.20.33,<1.0.0,>=0.20.6 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (0.25.2)
# Requirement already satisfied: everett<3.2.0,>=1.0.1 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet_ml) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (4.26.0)
# Requirement already satisfied: psutil>=5.6.3 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (7.2.2)
# Requirement already satisfied: python-box<7.0.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (2.34.2)
# Requirement already satisfied: rich>=13.3.2 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (15.0.0)
# Requirement already satisfied: semantic-version>=2.8.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (2.61.1)
# Requirement already satisfied: setuptools in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (70.2.0)
# Requirement already satisfied: simplejson in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (4.1.1)
# Requirement already satisfied: urllib3>=1.26.8 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.2 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (2.2.1)
# Requirement already satisfied: wurlitzer>=1.0.2 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from comet_ml) (3.1.1)
# Requirement already satisfied: configobj in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet_ml) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2026.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from requests>=2.18.4->comet_ml) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from requests>=2.18.4->comet_ml) (3.17)
# Requirement already satisfied: certifi>=2023.5.7 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from requests>=2.18.4->comet_ml) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from rich>=13.3.2->comet_ml) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from rich>=13.3.2->comet_ml) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/junyuan/venvs/torch-cu128/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)

# %%
import comet_ml
COMET_API_KEY = "REMOVED_COMET_KEY"

# Import PyTorch and other relevant libraries
import torch
import torch.nn as nn
import torch.optim as optim

# Import all remaining packages
import numpy as np
import os
import time
import functools
from IPython import display as ipythondisplay
from tqdm import tqdm
from scipy.io.wavfile import write
# !apt-get install abcmidi timidity > /dev/null 2>&1


# Check that we are using a GPU, if not switch runtimes
#   using Runtime > Change Runtime Type > GPU
assert torch.cuda.is_available(), "Please enable GPU from runtime settings"
# assert COMET_API_KEY != "", "Please insert your Comet API Key"

# %% [markdown]
# ### Load Dataset

# %%
# Download the dataset
import utils
songs = utils.load_training_data()

# Print one of the songs to inspect it in greater detail!
example_song = songs[0]
print("\nExample song: ")
print(example_song)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Download the dataset
#       2 import utils
# ----> 3 songs = utils.load_training_data()
#       4
#       5 # Print one of the songs to inspect it in greater detail!
#       6 example_song = songs[0]
#
# File ~/code/my-AI-roadmap/courses/introtodeeplearning/music-gen-lstm/utils.py:5, in load_training_data()
#       4 def load_training_data():
# ----> 5     with open(os.path.join(cwd, "data", "irish.abc"), "r") as f:
#       6         text = f.read()
#       7     songs = extract_song_snippet(text)
#
# NameError: name 'cwd' is not defined
